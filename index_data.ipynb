# %%
import os
import json
import numpy as np
import cupy as cp
import time
import random
from concurrent.futures import ThreadPoolExecutor, as_completed

def load_embeddings_from_jsonl(filename):
    vectors = []
    with open(filename, 'r', encoding='utf-8') as f:
        for line in f:
            obj = json.loads(line)
            vectors.append(obj['output_embeddings'][0])
    return np.array(vectors)

def sample_embeddings_from_files(file_list, n_samples=10000):
    """Randomly sample embeddings from multiple files for quantizer training."""
    samples = []
    total_collected = 0
    random.shuffle(file_list)
    for file in file_list:
        with open(file, 'r', encoding='utf-8') as f:
            lines = f.readlines()
            n = min(len(lines), n_samples - total_collected)
            if n <= 0:
                break
            chosen = random.sample(range(len(lines)), n)
            for idx in chosen:
                obj = json.loads(lines[idx])
                samples.append(obj['output_embeddings'][0])
                total_collected += 1
                if total_collected >= n_samples:
                    return np.array(samples)
    return np.array(samples)

def train_scalar_quantizer(embeddings):
    from cuvs.preprocessing.quantize import scalar
    embeddings_gpu = cp.asarray(embeddings)
    params = scalar.QuantizerParams(quantile=0.99)
    quantizer = scalar.train(params, embeddings_gpu)
    return quantizer

def train_binary_quantizer(embeddings):
    # For most binary quantization, explicit training is not needed.
    # This function is here for symmetry and future extensibility.
    return None

def binary_quantize_cuvs(embeddings, quantizer=None):
    try:
        from cuvs.preprocessing.quantize import binary
        start_time = time.time()
        embeddings_gpu = cp.asarray(embeddings)
        transformed = binary.transform(embeddings_gpu)
        quantization_time = time.time() - start_time
        # Free GPU memory
        del embeddings_gpu
        cp.get_default_memory_pool().free_all_blocks()
        return cp.asnumpy(transformed), quantization_time, True
    except Exception as e:
        import traceback
        print(f"Error during binary quantization: {str(e)}")
        print("Traceback:")
        print(traceback.format_exc())
        return None, 0.0, False

def scalar_quantize_cuvs(embeddings, quantizer):
    try:
        from cuvs.preprocessing.quantize import scalar
        embeddings_gpu = cp.asarray(embeddings)
        start_time = time.time()
        transformed = scalar.transform(quantizer, embeddings_gpu)
        quantization_time = time.time() - start_time
        # Free GPU memory
        del embeddings_gpu
        cp.get_default_memory_pool().free_all_blocks()
        return cp.asnumpy(transformed), quantization_time, True
    except Exception as e:
        import traceback
        print(f"Error during scalar quantization: {str(e)}")
        print("Traceback:")
        print(traceback.format_exc())
        return None, 0.0, False

def process_file(
    filepath, idx, output_dirs, quantization, quantize_from="full_precision", 
    full_precision_folder=None, scalar_quantizer=None, binary_quantizer=None
):
    try:
        print(f"Processing {filepath} ...")
        base = f"{idx:06d}"

        embeddings = None
        if "full_precision" in quantization or quantize_from == "raw":
            embeddings = load_embeddings_from_jsonl(filepath)

        if "full_precision" in quantization:
            fp_path = os.path.join(full_precision_folder, f"{base}_full.npy")
            np.save(fp_path, embeddings)
            print(f"Saved full-precision to {fp_path}")

        if quantize_from == "full_precision":
            fp_path = os.path.join(full_precision_folder, f"{base}_full.npy")
            if not os.path.exists(fp_path):
                if embeddings is None:
                    embeddings = load_embeddings_from_jsonl(filepath)
                np.save(fp_path, embeddings)
            quant_embeddings = np.load(fp_path)
        elif quantize_from == "raw":
            quant_embeddings = embeddings
        else:
            raise ValueError("quantize_from must be 'full_precision' or 'raw'")

        if "scalar" in quantization:
            sq_path = os.path.join(output_dirs["scalar"], f"{base}_scalar.npy")
            quantized, quant_time, success = scalar_quantize_cuvs(quant_embeddings, scalar_quantizer)
            if success:
                np.save(sq_path, quantized)
                print(f"Saved scalar quantized to {sq_path} (quantization time: {quant_time:.2f}s)")
            else:
                print(f"Scalar quantization failed for {filepath}")

        if "binary" in quantization:
            bq_path = os.path.join(output_dirs["binary"], f"{base}_binary.npy")
            quantized, quant_time, success = binary_quantize_cuvs(quant_embeddings, binary_quantizer)
            if success:
                np.save(bq_path, quantized)
                print(f"Saved binary quantized to {bq_path} (quantization time: {quant_time:.2f}s)")
            else:
                print(f"Binary quantization failed for {filepath}")

    except Exception as e:
        print(f"Failed to process {filepath}: {e}")

def embed_data(
    input_folder,
    output_base_folder,
    quantization=["full_precision", "scalar", "binary"],
    max_workers=2,
    quantize_from="full_precision",  # "full_precision" or "raw"
    n_samples=10000
):
    output_dirs = {}
    for q in quantization:
        if q != "full_precision":
            out_dir = os.path.join(output_base_folder, q)
            os.makedirs(out_dir, exist_ok=True)
            output_dirs[q] = out_dir

    full_precision_folder = os.path.join(output_base_folder, "full_precision")
    os.makedirs(full_precision_folder, exist_ok=True)

    files = sorted([os.path.join(input_folder, f) for f in os.listdir(input_folder) if f.endswith('.json')])

    # Train quantizers on random samples
    print("Sampling embeddings for quantizer training...")
    sample_array = sample_embeddings_from_files(files, n_samples=n_samples)
    print(f"Sampled {sample_array.shape[0]} embeddings for quantizer training.")

    scalar_quantizer = None
    binary_quantizer = None
    if "scalar" in quantization:
        print("Training scalar quantizer...")
        scalar_quantizer = train_scalar_quantizer(sample_array)
        print("Scalar quantizer trained.")
    if "binary" in quantization:
        print("Training binary quantizer (if needed)...")
        binary_quantizer = train_binary_quantizer(sample_array)
        print("Binary quantizer ready.")

    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = [
            executor.submit(
                process_file, f, idx, output_dirs, quantization, quantize_from, 
                full_precision_folder, scalar_quantizer, binary_quantizer
            )
            for idx, f in enumerate(files)
        ]
        for fut in as_completed(futures):
            fut.result()  # to raise exceptions if any

# %%
embed_data(
    input_folder="/home/ubuntu/amazon_ads/amazon_ads_data",
    output_base_folder="/home/ubuntu/amazon_ads/embeddings",
    quantization=["scalar"],
    max_workers=2,  # Keep this low to avoid memory issues
    quantize_from="full_precision",
    n_samples=500000
)
# Out:
# Sampling embeddings for quantizer training...
# Sampled 500000 embeddings for quantizer training.
# Training scalar quantizer...
# Scalar quantizer trained.
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-04614-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-04378-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000000_scalar.npy (quantization time: 0.01s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-01383-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000002_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-00244-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000003_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-08986-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000001_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-06792-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000004_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-02112-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000005_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-04969-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000006_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-05811-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000007_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-04501-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000008_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-01741-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000009_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-07188-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000010_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-02655-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000011_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-05303-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000012_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-01202-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000013_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-01977-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000014_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-05165-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000015_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-04098-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000016_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-04032-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000017_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-04518-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000018_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-08334-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000019_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-00926-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000020_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-05275-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000021_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-05198-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000022_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-03809-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000023_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-04219-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000024_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-03783-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000025_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-01822-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000026_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-02726-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000027_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-08302-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000028_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-02504-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000029_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-00218-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000030_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-07203-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000031_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-04258-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000032_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-08032-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000033_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-07776-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000034_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-05445-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000035_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-02446-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000036_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-07053-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000037_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-02016-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000038_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-01638-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000039_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-01443-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000040_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-05972-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000041_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-02880-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000042_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-01056-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000043_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-02710-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000044_scalar.npy (quantization time: 0.00s)Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000045_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-08461-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
#
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-00148-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000046_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-07985-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000047_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-00717-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000049_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-01111-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000048_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-07055-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000050_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-00465-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000051_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-04635-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000052_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-04561-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000053_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-02730-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000055_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-07871-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000054_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-02044-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000056_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-07243-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000057_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-00048-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000058_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-02891-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000059_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-01127-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000060_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-05482-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000061_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-05203-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000062_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-06654-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000063_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-06201-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000064_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-00440-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000065_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-06042-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000066_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-08762-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000067_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-05147-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000068_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-01947-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000069_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-01533-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000070_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-07866-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000071_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-01622-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000072_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-00145-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000073_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-07691-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000074_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-05252-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000075_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-07932-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000076_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-01574-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000077_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-07634-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000078_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-00274-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000079_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-03920-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000081_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-06441-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000080_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-08042-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000082_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-03437-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000083_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-06222-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000085_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-07220-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000084_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-04945-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000087_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-07000-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000086_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-03210-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000089_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-07606-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000088_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-07127-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000090_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-06845-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000091_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-03979-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000092_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-04112-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000093_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-07676-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000095_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-02096-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000094_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-04519-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000096_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-01134-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000097_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-05879-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000099_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-08703-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000098_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-03319-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000100_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-03453-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000101_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-05489-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000102_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-02971-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000103_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-02149-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000104_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-01068-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000105_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-04533-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000106_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-01456-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000107_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-07499-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000108_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-08748-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000109_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-04749-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000110_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-08098-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000111_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-04317-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000112_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-06619-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000113_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-05577-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000114_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-02512-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000115_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-06253-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000117_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-06126-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000116_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-08816-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000118_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-06430-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000119_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-03958-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000120_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-07019-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000121_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-04672-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000122_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-02260-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000123_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-01705-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000124_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-03536-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000125_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-03571-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000126_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-04551-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000127_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-01323-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000128_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-03336-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000129_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-01266-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000130_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-00680-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000131_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-03185-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000132_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-00469-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000133_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-05026-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000134_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-01209-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000135_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-07447-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000136_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-06631-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000137_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-06016-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000138_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-02644-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000139_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-04833-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000140_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-08724-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000141_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-08506-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000142_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-07327-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000143_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-03429-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000144_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-04975-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000145_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-07441-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000146_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-03868-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000147_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-01430-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000148_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-06034-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000149_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-07955-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000150_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-01971-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000151_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-04013-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000152_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-06146-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000153_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-07234-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000154_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-04542-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000155_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-00376-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000156_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-06664-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000157_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-04165-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000158_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-03029-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000159_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-07768-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000160_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-07226-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000161_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-03659-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000162_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-01462-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000163_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-01270-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000164_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-08227-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000165_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-04813-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000166_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-00778-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000167_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-00102-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000168_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-06974-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000169_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-01858-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000170_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-07952-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000171_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-08198-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000172_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-04393-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000173_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-01692-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000174_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-04691-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000175_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-08398-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000176_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-00860-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000177_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-02018-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000178_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-06772-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000179_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-03578-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000180_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-06578-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000181_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-03189-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000182_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-04886-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000183_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-03785-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000184_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-08634-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000185_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-01141-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000186_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-04302-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000187_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-06058-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000188_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-02582-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000189_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-08901-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000190_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-03618-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000191_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-08538-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000192_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-03775-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000193_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-08075-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000194_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-00654-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000195_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-02432-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000196_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-07878-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000197_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-02212-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000198_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-00006-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000199_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-04198-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000200_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-04936-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000201_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-03013-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000202_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-00142-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000203_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-07730-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000204_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-06147-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000205_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-06070-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000206_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-00392-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000207_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-07707-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000208_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-06009-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000209_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-05813-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/000210_scalar.npy (quantization time: 0.00s)
# ...
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-00478-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008928_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-00848-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008931_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-03244-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008930_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-08906-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008932_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-03320-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008933_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-01790-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008934_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-03049-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008935_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-04095-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008936_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-08888-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008937_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-05788-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008938_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-00339-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008939_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-00396-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008940_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-04509-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008941_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-03810-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008942_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-03545-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008943_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-06395-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008944_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-00799-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008945_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-01322-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008946_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-08896-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008947_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-06203-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008948_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-02605-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008949_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-06008-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008950_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-01582-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008951_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-07277-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008952_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-07501-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008953_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-06019-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008954_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-07177-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008955_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-05569-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008957_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-04436-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008956_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-06579-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008959_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-01059-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008958_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-08305-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008960_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-05015-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008961_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-04210-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008962_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-01023-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008963_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-00035-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008965_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-08955-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008964_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-03472-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008966_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-01033-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008967_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-04236-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008968_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-06142-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008969_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-08276-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008971_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-00592-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008970_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-06963-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008973_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-03981-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008972_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-03753-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008974_scalar.npy (quantization time: 0.00s)Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008975_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-02041-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
#
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-05143-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008977_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-02808-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008976_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-02895-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008979_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-07336-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008978_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-01011-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008980_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-01536-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008981_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-00947-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008982_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-07966-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008983_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-03863-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008984_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-05183-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008985_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-06053-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008986_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-00865-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008987_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-08795-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008988_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-08073-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008989_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-08067-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008990_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-04629-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008991_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-05047-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008992_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-03125-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008993_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-02312-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008995_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-00421-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008994_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-05486-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008996_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-06838-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008997_scalar.npy (quantization time: 0.00s)
# Processing /home/ubuntu/amazon_ads/amazon_ads_data/part-08587-6c18e020-9565-4603-a05c-42cdd450a8d5-c000.json ...
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008998_scalar.npy (quantization time: 0.00s)
# Saved scalar quantized to /home/ubuntu/amazon_ads/embeddings/scalar/008999_scalar.npy (quantization time: 0.00s)

# %%
# Write another code base to compare HNSW FAISS (FP, SQ) and CAGRA (FP, SQ) to create full sweep paretos on a subset of data
# (index build time, query throughput, query latency)

# %%
# Build a cagra index with quantized embeddings and save them-


# Build an hnsw index with faiss BQ vectors and quantize them-

# %%
import numpy as np
np.load("/home/ubuntu/amazon_ads/embeddings/binary/000001_bq.npy")
# Out:
# array([[131, 218, 191, ..., 223,  12, 184],
#        [231,  74,  37, ..., 220,   5, 248],
#        [135,  89, 189, ..., 126,   4, 112],
#        ...,
#        [215, 219,  25, ..., 214,  74, 176],
#        [180, 214, 159, ..., 214,  14, 169],
#        [174,  82, 189, ..., 126,   4, 189]], shape=(27547, 8), dtype=uint8)

# %%
import numpy as np
np.load("/home/ubuntu/data/home/ubuntu/amazon_ads/embeddings/half_precision/000004_fp16.npy").shape, np.load("/home/ubuntu/data/home/ubuntu/amazon_ads/embeddings/half_precision/000004_fp16.npy").dtype
# Out:
# ((27548, 64), dtype('float16'))

# %%
np.load("/home/ubuntu/data/home/ubuntu/amazon_ads/embeddings/full_precision/000004_full.npy").shape, np.load("/home/ubuntu/data/home/ubuntu/amazon_ads/embeddings/full_precision/000004_full.npy").dtype
# Out:
# ((27548, 64), dtype('float64'))

# %%
# Out:
# 247932000
